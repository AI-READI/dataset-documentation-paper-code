# %% [markdown]
# # Comparison of the content of the dataset documentation approaches

# %% [markdown]
# Before using add the "metadata-elements.xlsx" file in the "inputs" folder (see the README for details)

# %% [markdown]
# ## Import required packages and set plot settings

# %%
import itertools
import math

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sentence_transformers import SentenceTransformer

# %%
sns.set(
    font="Franklin Gothic Book",
    rc={
        "axes.axisbelow": False,
        "axes.edgecolor": "lightgrey",
        "axes.facecolor": "None",
        "axes.grid": False,
        "axes.labelcolor": "dimgrey",
        "axes.spines.right": False,
        "axes.spines.top": False,
        "figure.facecolor": "white",
        "lines.solid_capstyle": "round",
        "patch.edgecolor": "w",
        "patch.force_edgecolor": True,
        "text.color": "dimgrey",
        "xtick.bottom": False,
        "xtick.color": "dimgrey",
        "xtick.direction": "out",
        "xtick.top": False,
        "ytick.color": "dimgrey",
        "ytick.direction": "out",
        "ytick.left": False,
        "ytick.right": False,
    },
)
sns.set_context(
    "notebook", rc={"font.size": 16, "axes.titlesize": 20, "axes.labelsize": 18}
)

colors = ["#073b4c", "#ffd166", "#06d6a0"]
patterns = ["/", "\\", "-", "+", "x", "o", "O", ".", "*", "|"]

# %% [markdown]
# ## Load data

# %%
dfs = pd.read_excel(
    "inputs/dataset/primary/metadata-elements.xlsx", sheet_name=None
)
df_list = dfs["List"]
del dfs["List"]
del dfs["codebook"]
display(dfs["Datasheet"])
display(df_list)
# Out:
#                                     Question or field  \
# 0   For what purpose was the dataset created? Was ...
# 1   Who created the dataset (e.g., which team, res...
# 2   Who funded the creation of the dataset? If the...
# 3                                 Any other comments?
# 4   What do the instances that comprise the datase...
# ..                                                ...
# 61  Will the dataset be updated (e.g., to correct ...
# 62  If the dataset relates to people, are there ap...
# 63  Will older versions of the dataset continue to...
# 64  If others want to extend/augment/build on/cont...
# 65                                Any other comments?
#
#                                      Metadata element
# 0   Description of the purpose for creating the da...
# 1       Information about the creators of the dataset
# 2            Details about the funding of the dataset
# 3                                                 NaN
# 4   Description of the instances included in the d...
# ..                                                ...
# 61             Description of the dataset update plan
# 62        Description of the dataset retention policy
# 63  Description of the management plan for older v...
# 64  Description of the methods to contribute to th...
# 65                                                NaN
#
# [66 rows x 2 columns]
#                                       Metadata element isCritical
# 0                           Description of the dataset        yes
# 1               Information about dataset audit/review         no
# 2    Information about the dataset versioning approach         no
# 3    Version of the dataset associated with this da...        yes
# 4    Information about the dataset documentation fo...         no
# ..                                                 ...        ...
# 133                            Link to design document         no
# 134           Description of the relevance of the data         no
# 135  Description and results of the requirement tes...         no
# 136  Description and results of the adversarial tes...         no
# 137           Description and results of other testing         no
#
# [138 rows x 2 columns]

# %% [markdown]
# ## Check if any metadata elements are too similar and should be regrouped into one

# %%
# Get a list of all metadata elements
metadata_elements_list = []
for sheet, df in dfs.items():
    metadata_elements_list += list(df["Metadata element"])
metadata_elements_list = [
    x for x in metadata_elements_list if str(x) != "nan"
]  # remove nan value
metadata_elements_list = [
    s.strip() for s in metadata_elements_list
]  # remove spaces ends of string
metadata_elements_list = list(set(metadata_elements_list))  # keep only unique entries

critical_df_list = df_list[df_list["isCritical"] == "yes"]
critical_metadata_elements_list = list(critical_df_list["Metadata element"])
df = pd.DataFrame(metadata_elements_list, columns=["Metadata element"])
# df.to_excel("outputs/metadata_elements_list.xlsx", index=False)
print("There are ", len(metadata_elements_list), " metadata elements")
print("There are ", len(critical_metadata_elements_list), " critical metadata elements")
display(df)
# Out:
# There are  138  metadata elements
# There are  112  critical metadata elements
#                                       Metadata element
# 0             Description of the data maintenance plan
# 1    Description of the potential impact of the dat...
# 2     Description of the process to access to raw data
# 3    Information about the metadata repository and ...
# 4    Description and results of the requirement tes...
# ..                                                 ...
# 133  Description of the involvement of the particip...
# 134                 Description of the aggregated data
# 135  Information about the dataset versioning approach
# 136  Description of the external resources the data...
# 137  Description of the subpopulations identified i...
#
# [138 rows x 1 columns]

# %%
# Encode metadata elements
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(metadata_elements_list)

# Get and save cosine similarity scores
similar_rows = []
unique_index_pairs = list(
    itertools.combinations(list(range(len(metadata_elements_list))), 2)
)
for index_pair in unique_index_pairs:
    i = index_pair[0]
    j = index_pair[1]
    element1 = metadata_elements_list[i]
    element2 = metadata_elements_list[j]
    cosine_similarity = np.dot(embeddings[i], embeddings[j]) / (
        np.linalg.norm(embeddings[i]) * np.linalg.norm(embeddings[j])
    )
    similar_rows.append([element1, element2, cosine_similarity])
df_similar = pd.DataFrame(
    similar_rows, columns=["Element 1", "Element 2", "cosine similarity score"]
)
df_similar = df_similar.sort_values(by="cosine similarity score", ascending=False)
display(df_similar)
df_similar.to_excel("outputs/metadata_elements_similarity.xlsx", index=False)
# Out:
#                                               Element 1  \
# 3305  Version of the dataset associated with this da...
# 7723  Description of the undesirable uses of the dat...
# 9056  Description of the purpose for creating the da...
# 7580  Information about the authors of this dataset ...
# 3286  Version of the dataset associated with this da...
# ...                                                 ...
# 4211        Description of the dataset retention policy
# 6059               Description of other transformations
# 5440                            Link to design document
# 7221                                   Last update date
# 1612      Description and handling of mismatched values
#
#                                               Element 2  \
# 3305  Information about the dataset documentation fo...
# 7723     Description of the intended use of the dataset
# 9056     Description of the intended use of the dataset
# 7580  Information about the dataset documentation fo...
# 3286  Information about the authors of this dataset ...
# ...                                                 ...
# 4211                            Link to design document
# 6059          Recommendations when sampling the dataset
# 5440  Assumption in data fields not made explicit in...
# 7221  Description of the strategies to avoid undesir...
# 1612                            Link to design document
#
#       cosine similarity score
# 3305                 0.954538
# 7723                 0.908756
# 9056                 0.896263
# 7580                 0.877440
# 3286                 0.868454
# ...                       ...
# 4211                -0.096966
# 6059                -0.099885
# 5440                -0.106389
# 7221                -0.114775
# 1612                -0.158817
#
# [9453 rows x 3 columns]

# %% [markdown]
# Note: We ran this on the first version of our metadata element assignment where we had 146 unique metadata elements. We manually reviewed each pair of elements in descending order of cosine similarity value. We noticed that below a similarity score of 0.75, the elements were not similar and therefore we did not manually check below that. We identified 7 pairs of metadata elements that could be regrouped into one and ended up with a total of 139 unique metadata elements after that.

# %% [markdown]
# ## View metadata elements and related questions/fields side-by-side for further review

# %%
documentation_list = list(dfs.keys())
retrouped_list = []
for metadata_element in metadata_elements_list:
    dict_questions = {}
    for sheet, df in dfs.items():
        df = df.loc[df["Metadata element"] == metadata_element]
        dict_questions[sheet] = list(df["Question or field"])
    count = 0
    not_all_nan = True
    while not_all_nan:
        row = []
        if count == 0:
            row.append(metadata_element)
        else:
            row.append(math.nan)
        for sheet in documentation_list:
            sheet_list = dict_questions[sheet]
            if len(sheet_list) > count:
                row.append(sheet_list[count])
            else:
                row.append(math.nan)
        if all(i != i for i in row):
            not_all_nan = False
        else:
            retrouped_list.append(row)
        count += 1
df_regrouped = pd.DataFrame(
    retrouped_list, columns=["Metadata element"] + documentation_list
)
display(df_regrouped)
df_regrouped.to_excel(
    "outputs/metadata_elements_regrouped_all_documentation_approaches.xlsx", index=False
)
# Out:
#                                       Metadata element  \
# 0             Description of the data maintenance plan
# 1    Description of the potential impact of the dat...
# 2     Description of the process to access to raw data
# 3    Information about the metadata repository and ...
# 4    Description and results of the requirement tes...
# ..                                                 ...
# 301  Information about the dataset versioning approach
# 302  Description of the external resources the data...
# 303  Description of the subpopulations identified i...
# 304                                                NaN
# 305                                                NaN
#
#                                              Datasheet  \
# 0                                                  NaN
# 1    Has an analysis of the potential impact of the...
# 2    Was the “raw” data saved in addition to the pr...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302  Is the dataset self-contained, or does it link...
# 303  Does the dataset identify any subpopulations? ...
# 304                                                NaN
# 305                                                NaN
#
#                                Dataset Nutrition Label  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Was the raw data saved in addition to the prep...
# 3    Does the dataset have a metadata repository or...
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303      Does the dataset identify any subpopulations?
# 304  Indicate subpopulation distributions within th...
# 305  Which communities, groups, or identities are r...
#
#                           Accountability Documentation  \
# 0    Who will maintain the dataset? Is there a main...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Requirement tested: ( Requirement from require...
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303                 Population: population represented
# 304                                                NaN
# 305                                                NaN
#
#                                            Healthsheet  \
# 0                                                  NaN
# 1    Has an analysis of the potential impact of the...
# 2    Was the “raw” data (post de-identification) sa...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301  Does the dataset get released as static versio...
# 302  Is the dataset self-contained, or does it link...
# 303  Does the dataset identify any demographic subp...
# 304                                                NaN
# 305                                                NaN
#
#                                              Data Card
# 0    Summarize the maintenance plan for the dataset...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
#
# [306 rows x 6 columns]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Comparison matrix

# %%
df_comparison = pd.DataFrame(
    index=list(dfs.keys()), columns=list(dfs.keys()), dtype=float
)
for documentation1 in df_comparison.index:
    df1 = dfs[documentation1]
    for documentation2 in df_comparison.columns:
        df2 = dfs[documentation2]
        df_comparison.loc[documentation1, documentation2] = (
            len(
                [
                    i
                    for i in list(df1["Metadata element"])
                    if i in list(df2["Metadata element"])
                ]
            )
            / len(list(df1["Metadata element"]))
            * 100
        )
labels = []
for doc in dfs.keys():
    if len(doc.split()) > 1:
        doc = "\n".join(doc.split())
    labels.append(doc)

df_comparison.to_excel("outputs/metadata_elements_comparison_matrix.xlsx", index=False)
ax = sns.heatmap(
    df_comparison,
    xticklabels=labels,
    yticklabels=labels,
    annot=True,
    cmap="Blues",
    fmt="0.0f",
    cbar_kws={"label": "% of metadata elements from source \n found in taget"},
)
ax.figure.axes[-1].yaxis.label.set_size(11)
ax.set_xlabel("Target", fontsize=14)
ax.set_ylabel("Source", fontsize=14)
plt.tight_layout()
plt.savefig("outputs/metadata_elements_comparison_matrix.png", dpi=200)

# %% [markdown]
# ### Occurence of metadata elements accross dataset documentation

# %%
elements_count_list = []
for metadata_element in metadata_elements_list:
    row = [metadata_element]
    for sheet, df in dfs.items():
        if metadata_element in list(df["Metadata element"]):
            row.append("yes")
        else:
            row.append("no")
    row.append(len([i for i in row if i == "yes"]))
    if metadata_element in critical_metadata_elements_list:
        row.append("yes")
    else:
        row.append("no")
    elements_count_list.append(row)
df_element_count = pd.DataFrame(
    elements_count_list,
    columns=["Metadata element"] + list(dfs.keys()) + ["Count", "Critical"],
)
df_element_count = df_element_count.sort_values(by=["Count"], ascending=False)
df_element_count.to_excel("outputs/metadata_elements_count.xlsx", index=False)
display(df_element_count)
# Out:
#                                       Metadata element Datasheet  \
# 42           Description of the dataset sharing method       yes
# 31            Details about the funding of the dataset       yes
# 90                            Dataset publication date       yes
# 116        Information about the owners of the dataset       yes
# 121         Description of the data collection process       yes
# ..                                                 ...       ...
# 130  Assumption in data fields not made explicit in...        no
# 133  Description of the involvement of the particip...        no
# 131                  Known issues with data collection        no
# 135  Information about the dataset versioning approach        no
# 134                 Description of the aggregated data        no
#
#     Dataset Nutrition Label Accountability Documentation Healthsheet  \
# 42                      yes                          yes         yes
# 31                      yes                          yes         yes
# 90                      yes                          yes         yes
# 116                     yes                          yes         yes
# 121                     yes                          yes         yes
# ..                      ...                          ...         ...
# 130                     yes                           no          no
# 133                     yes                           no          no
# 131                     yes                           no          no
# 135                      no                           no         yes
# 134                      no                           no          no
#
#     Data Card  Count Critical
# 42        yes      5      yes
# 31        yes      5      yes
# 90        yes      5      yes
# 116       yes      5      yes
# 121       yes      5      yes
# ..        ...    ...      ...
# 130        no      1      yes
# 133        no      1      yes
# 131        no      1      yes
# 135        no      1       no
# 134       yes      1      yes
#
# [138 rows x 8 columns]

# %%
## Number of metadata elements and unique metadata elements per dataset documentation approach
count_metadata_elements = []
count_unique_metadata_elements = []
count_missing_critical_metadata_elements = []
labels = []
for doc in list(dfs.keys()):
    count_metadata_elements.append(df_element_count[doc].value_counts().get("yes", 0))
    count_unique_metadata_elements.append(
        len(
            df_element_count[
                (df_element_count[doc] == "yes") & (df_element_count["Count"] == 1)
            ]
        )
    )
    count_missing_critical_metadata_elements.append(
        len(
            df_element_count[
                (df_element_count[doc] == "yes")
                & (df_element_count["Critical"] == "yes")
            ]
        )
    )
    if len(doc.split()) > 1:
        doc = "\n".join(doc.split())
    labels.append(doc)

# plot
fig, ax = plt.subplots(1, 1, figsize=(9, 6))

width = 0.25
y_list = [
    count_metadata_elements,
    count_unique_metadata_elements,
    count_missing_critical_metadata_elements,
]
labels_list = ["Total", "Unique", "Critical"]
x = np.arange(len(labels))
count = 0
for y in y_list:
    bars = ax.bar(
        x + width * count,
        y,
        width,
        color=colors[count],
        hatch=patterns[count],
        label=labels_list[count],
    )
    ax.bar_label(bars, padding=3)
    count += 1

ax.set_xticks(x + width, labels, fontsize=14)
ax.set_ylabel("Number of metadata elements", fontsize=14)
ax.set_axisbelow(True)
leg = ax.legend(loc="upper left", labelspacing=1, handlelength=2.5, facecolor="white")
for patch in leg.get_patches():
    patch.set_height(14)
    patch.set_y(-5)
ax.grid(axis="y", color="0.95")
plt.grid(color="0.95", axis="y")

fig.tight_layout()
fig.savefig("outputs/metadata_elements_view.png", dpi=200)

# %%
df_common = df_element_count[df_element_count["Count"] == 5]
df_unique = df_element_count[df_element_count["Count"] == 1]
print(
    "There are",
    len(df_common),
    "metadata elements that are found in all five documentation approaches",
)
print(
    "There are",
    len(df_unique),
    "metadata elements that are found only in one of the five documentation approaches",
)
display(df_common)
# Out:
# There are 7 metadata elements that are found in all five documentation approaches
# There are 76 metadata elements that are found only in one of the five documentation approaches
#                                    Metadata element Datasheet  \
# 42        Description of the dataset sharing method       yes
# 31         Details about the funding of the dataset       yes
# 90                         Dataset publication date       yes
# 116     Information about the owners of the dataset       yes
# 121      Description of the data collection process       yes
# 119  Description of the intended use of the dataset       yes
# 71           Description of the dataset update plan       yes
#
#     Dataset Nutrition Label Accountability Documentation Healthsheet  \
# 42                      yes                          yes         yes
# 31                      yes                          yes         yes
# 90                      yes                          yes         yes
# 116                     yes                          yes         yes
# 121                     yes                          yes         yes
# 119                     yes                          yes         yes
# 71                      yes                          yes         yes
#
#     Data Card  Count Critical
# 42        yes      5      yes
# 31        yes      5      yes
# 90        yes      5      yes
# 116       yes      5      yes
# 121       yes      5      yes
# 119       yes      5      yes
# 71        yes      5      yes

# %%
# Least common
for dataset_documentation in dfs.keys():
    print("----- Unique metadata description in " + dataset_documentation + " -----")
    df_unique = df_element_count[
        (df_element_count["Count"] == 1)
        & (df_element_count[dataset_documentation] == "yes")
    ]
    display(df_unique)
# Out:
# ----- Unique metadata description in Datasheet -----
#                                      Metadata element Datasheet  \
# 30  Description of the possibilities to identify i...       yes
#
#    Dataset Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 30                      no                           no          no        no
#
#     Count Critical
# 30      1      yes
# ----- Unique metadata description in Dataset Nutrition Label -----
#                                       Metadata element Datasheet  \
# 3    Information about the metadata repository and ...        no
# 9    Description of the proxy characteristics in th...        no
# 7     Description of representation issues in the data        no
# 23   Required domain-specific knowledge for proper ...        no
# 33                                            Keywords        no
# 39   Information about the people consulted to crea...        no
# 75       Description of issues related to this dataset        no
# 82   Information about the format/structure of the ...        no
# 88            Description of the individual-level data        no
# 118  Familiarity of creators of this dataset docume...        no
# 117  Description of the strategies to avoid undesir...        no
# 130  Assumption in data fields not made explicit in...        no
# 133  Description of the involvement of the particip...        no
# 131                  Known issues with data collection        no
#
#     Dataset Nutrition Label Accountability Documentation Healthsheet  \
# 3                       yes                           no          no
# 9                       yes                           no          no
# 7                       yes                           no          no
# 23                      yes                           no          no
# 33                      yes                           no          no
# 39                      yes                           no          no
# 75                      yes                           no          no
# 82                      yes                           no          no
# 88                      yes                           no          no
# 118                     yes                           no          no
# 117                     yes                           no          no
# 130                     yes                           no          no
# 133                     yes                           no          no
# 131                     yes                           no          no
#
#     Data Card  Count Critical
# 3          no      1      yes
# 9          no      1      yes
# 7          no      1      yes
# 23         no      1      yes
# 33         no      1      yes
# 39         no      1      yes
# 75         no      1      yes
# 82         no      1      yes
# 88         no      1       no
# 118        no      1      yes
# 117        no      1      yes
# 130        no      1      yes
# 133        no      1      yes
# 131        no      1      yes
# ----- Unique metadata description in Accountability Documentation -----
#                                       Metadata element Datasheet  \
# 5    Description of the process for creating this d...        no
# 4    Description and results of the requirement tes...        no
# 41                 Description of the privacy handling        no
# 72           Expectations for people using the dataset        no
# 70                                    Last update date        no
# 62        Description of the data quality measurements        no
# 58   Description of what is being tested in the dat...        no
# 50                     Known caveats about the dataset        no
# 52                  Link to requirements specification        no
# 47                             Link to design document        no
# 17                     Description of related datasets        no
# 24   Description and results of the adversarial tes...        no
# 32            Description of the relevance of the data        no
# 40          Information about the data collection cost        no
# 89              Description of the data rating process        no
# 92   Description of the data distribution in the da...        no
# 86            Description and results of other testing        no
# 112                          List of related documents        no
# 107      Description of the dataset processing process        no
# 125  Description of domain specific concepts for ge...        no
# 124  Description of the ethical impact of the data ...        no
#
#     Dataset Nutrition Label Accountability Documentation Healthsheet  \
# 5                        no                          yes          no
# 4                        no                          yes          no
# 41                       no                          yes          no
# 72                       no                          yes          no
# 70                       no                          yes          no
# 62                       no                          yes          no
# 58                       no                          yes          no
# 50                       no                          yes          no
# 52                       no                          yes          no
# 47                       no                          yes          no
# 17                       no                          yes          no
# 24                       no                          yes          no
# 32                       no                          yes          no
# 40                       no                          yes          no
# 89                       no                          yes          no
# 92                       no                          yes          no
# 86                       no                          yes          no
# 112                      no                          yes          no
# 107                      no                          yes          no
# 125                      no                          yes          no
# 124                      no                          yes          no
#
#     Data Card  Count Critical
# 5          no      1      yes
# 4          no      1       no
# 41         no      1      yes
# 72         no      1       no
# 70         no      1      yes
# 62         no      1      yes
# 58         no      1      yes
# 50         no      1      yes
# 52         no      1       no
# 47         no      1       no
# 17         no      1       no
# 24         no      1       no
# 32         no      1       no
# 40         no      1       no
# 89         no      1       no
# 92         no      1      yes
# 86         no      1       no
# 112        no      1      yes
# 107        no      1      yes
# 125        no      1       no
# 124        no      1      yes
# ----- Unique metadata description in Healthsheet -----
#                                       Metadata element Datasheet  \
# 73       Description of the accessibility measurements        no
# 60   Description of the regulation preventing demog...        no
# 63   Description of the choice(s) of language for c...        no
# 53       Number of subjects represented in the dataset        no
# 54   Description of the factors in the data that mi...        no
# 57   Description of the confounding factors that mi...        no
# 43   Description of the strategies to avoid reident...        no
# 48              Countries where the data was collected        no
# 11                  Guidelines for creating new labels        no
# 105        Description of the study inclusion criteria        no
# 95   Information about the dataset documentation fo...        no
# 135  Information about the dataset versioning approach        no
#
#     Dataset Nutrition Label Accountability Documentation Healthsheet  \
# 73                       no                           no         yes
# 60                       no                           no         yes
# 63                       no                           no         yes
# 53                       no                           no         yes
# 54                       no                           no         yes
# 57                       no                           no         yes
# 43                       no                           no         yes
# 48                       no                           no         yes
# 11                       no                           no         yes
# 105                      no                           no         yes
# 95                       no                           no         yes
# 135                      no                           no         yes
#
#     Data Card  Count Critical
# 73         no      1      yes
# 60         no      1      yes
# 63         no      1      yes
# 53         no      1      yes
# 54         no      1      yes
# 57         no      1      yes
# 43         no      1      yes
# 48         no      1      yes
# 11         no      1      yes
# 105        no      1      yes
# 95         no      1       no
# 135        no      1       no
# ----- Unique metadata description in Data Card -----
#                                       Metadata element Datasheet  \
# 6                           Dataset maintenance status        no
# 8    Recommendations when this data is used with ot...        no
# 13         Description of the dataset deletion process        no
# 25   Description of benefits of the dataset compare...        no
# 21          Description of the data exclusion criteria        no
# 67   Information about the first version of the dat...        no
# 65           Recommendations when sampling the dataset        no
# 51          Recommendations when used in AI/ML systems        no
# 55                Description of other transformations        no
# 44   Description of the process to mitigate risk fr...        no
# 45            Description and handling of the outliers        no
# 12       Description and handling of mismatched values        no
# 14          Description of the data validation process        no
# 101  Description of the alignment of the dataset wi...        no
# 98                          Description of annotations        no
# 96   Description of limitations of the dataset comp...        no
# 94             Description of the joint inputs sourced        no
# 80   Definition of the acronyms and concepts used i...        no
# 83   Description of the redacted or anonymized feat...        no
# 84   Description of the data selection and inclusio...        no
# 87                    Statistics about each data field        no
# 120                         Details of the data points        no
# 115           Description of the human data attributes        no
# 106  Description of the prerequisites to access thi...        no
# 110  Information about risks when used with other data        no
# 126           Information about the dataset publishers        no
# 122        Description of the dimensionality reduction        no
# 134                 Description of the aggregated data        no
#
#     Dataset Nutrition Label Accountability Documentation Healthsheet  \
# 6                        no                           no          no
# 8                        no                           no          no
# 13                       no                           no          no
# 25                       no                           no          no
# 21                       no                           no          no
# 67                       no                           no          no
# 65                       no                           no          no
# 51                       no                           no          no
# 55                       no                           no          no
# 44                       no                           no          no
# 45                       no                           no          no
# 12                       no                           no          no
# 14                       no                           no          no
# 101                      no                           no          no
# 98                       no                           no          no
# 96                       no                           no          no
# 94                       no                           no          no
# 80                       no                           no          no
# 83                       no                           no          no
# 84                       no                           no          no
# 87                       no                           no          no
# 120                      no                           no          no
# 115                      no                           no          no
# 106                      no                           no          no
# 110                      no                           no          no
# 126                      no                           no          no
# 122                      no                           no          no
# 134                      no                           no          no
#
#     Data Card  Count Critical
# 6         yes      1      yes
# 8         yes      1      yes
# 13        yes      1      yes
# 25        yes      1       no
# 21        yes      1      yes
# 67        yes      1       no
# 65        yes      1      yes
# 51        yes      1      yes
# 55        yes      1       no
# 44        yes      1      yes
# 45        yes      1      yes
# 12        yes      1      yes
# 14        yes      1      yes
# 101       yes      1       no
# 98        yes      1      yes
# 96        yes      1       no
# 94        yes      1      yes
# 80        yes      1      yes
# 83        yes      1      yes
# 84        yes      1      yes
# 87        yes      1       no
# 120       yes      1       no
# 115       yes      1      yes
# 106       yes      1      yes
# 110       yes      1      yes
# 126       yes      1      yes
# 122       yes      1      yes
# 134       yes      1      yes
