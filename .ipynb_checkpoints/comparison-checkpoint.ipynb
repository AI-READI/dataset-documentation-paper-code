# %% [markdown]
# # Comparison of the content of the dataset documentation approaches

# %% [markdown]
# Before using add the "metadata-elements-comparison.xlsx" file in the "inputs" folder (see the README for details)

# %% [markdown]
# ## Import required packages and set plot settings

# %%
import itertools
import math

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sentence_transformers import SentenceTransformer

# %%
sns.set(
    font="Franklin Gothic Book",
    rc={
        "axes.axisbelow": False,
        "axes.edgecolor": "lightgrey",
        "axes.facecolor": "None",
        "axes.grid": False,
        "axes.labelcolor": "dimgrey",
        "axes.spines.right": False,
        "axes.spines.top": False,
        "figure.facecolor": "white",
        "lines.solid_capstyle": "round",
        "patch.edgecolor": "w",
        "patch.force_edgecolor": True,
        "text.color": "dimgrey",
        "xtick.bottom": False,
        "xtick.color": "dimgrey",
        "xtick.direction": "out",
        "xtick.top": False,
        "ytick.color": "dimgrey",
        "ytick.direction": "out",
        "ytick.left": False,
        "ytick.right": False,
    },
)
sns.set_context(
    "notebook", rc={"font.size": 16, "axes.titlesize": 20, "axes.labelsize": 18}
)

colors = ["#073b4c", "#ffd166", "#06d6a0"]
patterns = ["/", "\\", "-", "+", "x", "o", "O", ".", "*", "|"]

# %% [markdown]
# ## Load data

# %%
dfs = pd.read_excel(
    "inputs/dataset/primary/metadata-elements-comparison.xlsx", sheet_name=None
)
df_list = dfs["List"]
del dfs["List"]
display(dfs["Datasheet"])
display(df_list)
# Out:
#                                     Question or field  \
# 0   For what purpose was the dataset created? Was ...
# 1   Who created the dataset (e.g., which team, res...
# 2   Who funded the creation of the dataset? If the...
# 3                                 Any other comments?
# 4   What do the instances that comprise the datase...
# ..                                                ...
# 61  Will the dataset be updated (e.g., to correct ...
# 62  If the dataset relates to people, are there ap...
# 63  Will older versions of the dataset continue to...
# 64  If others want to extend/augment/build on/cont...
# 65                                Any other comments?
#
#                                      Metadata element
# 0   Description of the purpose for creating the da...
# 1       Information about the creators of the dataset
# 2            Details about the funding of the dataset
# 3                                                 NaN
# 4   Description of the instances included in the d...
# ..                                                ...
# 61             Description of the dataset update plan
# 62        Description of the dataset retention policy
# 63  Description of the management plan for older v...
# 64  Description of the methods to contribute to th...
# 65                                                NaN
#
# [66 rows x 2 columns]
#                                       Metadata element  \
# 0                           Description of the dataset
# 1               Information about dataset audit/review
# 2    Information about the dataset versioning approach
# 3    Version of the dataset associated with this da...
# 4    Information about the dataset documentation fo...
# ..                                                 ...
# 134                            Link to design document
# 135           Description of the relevance of the data
# 136  Description and results of the requirement tes...
# 137  Description and results of the adversarial tes...
# 138           Description and results of other testing
#
#     Critical for clinical research datasets  Anna  Lingling  Kyongmi  Fritz
# 0                                       Yes   NaN       NaN      NaN    NaN
# 1                                        No   NaN       NaN      NaN    NaN
# 2                                        No   NaN       NaN      NaN    NaN
# 3                                       Yes   NaN       NaN      NaN    NaN
# 4                                        No   NaN       NaN      NaN    NaN
# ..                                      ...   ...       ...      ...    ...
# 134                                      No   NaN       NaN      NaN    NaN
# 135                                      No   NaN       NaN      NaN    NaN
# 136                                      No   NaN       NaN      NaN    NaN
# 137                                      No   NaN       NaN      NaN    NaN
# 138                                      No   NaN       NaN      NaN    NaN
#
# [139 rows x 6 columns]

# %% [markdown]
# ## Check if any metadata elements are too similar and should be regrouped into one

# %%
# Get a list of all metadata elements
metadata_elements_list = []
for sheet, df in dfs.items():
    metadata_elements_list += list(df["Metadata element"])
metadata_elements_list = list(set(metadata_elements_list))
metadata_elements_list = [
    x for x in metadata_elements_list if str(x) != "nan"
]  # remove nan value
critical_df_list = df_list[df_list["Critical for clinical research datasets"] == "Yes"]
critical_metadata_elements_list = list(critical_df_list["Metadata element"])
df = pd.DataFrame(metadata_elements_list, columns=["Metadata element"])
# df.to_excel("outputs/metadata_elements_list.xlsx", index=False)
print("There are ", len(metadata_elements_list), " metadata elements")
print("There are ", len(critical_metadata_elements_list), " critical metadata elements")
display(df)
# Out:
# There are  139  metadata elements
# There are  101  critical metadata elements
#                                       Metadata element
# 0     Description of the process to access to raw data
# 1    Description of what is being tested in the dat...
# 2           Description of the recommended data splits
# 3          Description of the dimensionality reduction
# 4        Information about the creators of the dataset
# ..                                                 ...
# 134     Description of the intended use of the dataset
# 135  Description of domain specific concepts for ge...
# 136                                           Keywords
# 137  Description of the management plan for older v...
# 138  Description of the process for creating this d...
#
# [139 rows x 1 columns]

# %%
# Encode metadata elements
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(metadata_elements_list)

# Get and save cosine similarity scores
similar_rows = []
unique_index_pairs = list(
    itertools.combinations(list(range(len(metadata_elements_list))), 2)
)
for index_pair in unique_index_pairs:
    i = index_pair[0]
    j = index_pair[1]
    element1 = metadata_elements_list[i]
    element2 = metadata_elements_list[j]
    cosine_similarity = np.dot(embeddings[i], embeddings[j]) / (
        np.linalg.norm(embeddings[i]) * np.linalg.norm(embeddings[j])
    )
    similar_rows.append([element1, element2, cosine_similarity])
df_similar = pd.DataFrame(
    similar_rows, columns=["Element 1", "Element 2", "cosine similarity score"]
)
df_similar = df_similar.sort_values(by="cosine similarity score", ascending=False)
display(df_similar)
df_similar.to_excel("outputs/metadata_elements_similarity.xlsx", index=False)
# Out:
#                                               Element 1  \
# 2694  Information about the dataset documentation fo...
# 7633  Description of the undesirable uses of the dat...
# 3370  Description of the purpose for creating the da...
# 1334  Information the people consulted to create thi...
# 2717  Information about the dataset documentation fo...
# ...                                                 ...
# 2554          Recommendations when sampling the dataset
# 6768  Assumption in data fields not made explicit in...
# 1443                 Other dataset metrics besides size
# 6147                                   Last update date
# 6540      Description and handling of mismatched values
#
#                                               Element 2  \
# 2694  Version of the dataset associated with this da...
# 7633     Description of the intended use of the dataset
# 3370     Description of the intended use of the dataset
# 1334  Description of the process for creating this d...
# 2717  Information about the authors of this dataset ...
# ...                                                 ...
# 2554               Description of other transformations
# 6768                            Link to design document
# 1443    Description of the consent revocation mechanism
# 6147  Description of the strategies to avoid undesir...
# 6540                            Link to design document
#
#       cosine similarity score
# 2694                 0.954538
# 7633                 0.908756
# 3370                 0.896263
# 1334                 0.880714
# 2717                 0.877440
# ...                       ...
# 2554                -0.099885
# 6768                -0.106389
# 1443                -0.110900
# 6147                -0.114775
# 6540                -0.158817
#
# [9591 rows x 3 columns]

# %% [markdown]
# Note: We ran this on the first version of our metadata element assignment where we had 146 unique metadata elements. We manually reviewed each pair of elements in descending order of cosine similarity value. We noticed that below a similarity score of 0.75, the elements were not similar and therefore we did not manually check below that. We identified 6 pairs of metadata elements that could be regrouped into one and ended up with a total of 140 unique metadata elements after that.

# %% [markdown]
# ## View metadata elements and related questions/fields side-by-side for further review

# %%
documentation_list = list(dfs.keys())
retrouped_list = []
for metadata_element in metadata_elements_list:
    dict_questions = {}
    for sheet, df in dfs.items():
        df = df.loc[df["Metadata element"] == metadata_element]
        dict_questions[sheet] = list(df["Question or field"])
    count = 0
    not_all_nan = True
    while not_all_nan:
        row = []
        if count == 0:
            row.append(metadata_element)
        else:
            row.append(math.nan)
        for sheet in documentation_list:
            sheet_list = dict_questions[sheet]
            if len(sheet_list) > count:
                row.append(sheet_list[count])
            else:
                row.append(math.nan)
        if all(i != i for i in row):
            not_all_nan = False
        else:
            retrouped_list.append(row)
        count += 1
df_regrouped = pd.DataFrame(
    retrouped_list, columns=["Metadata element"] + documentation_list
)
display(df_regrouped)
df_regrouped.to_excel(
    "outputs/metadata_elements_regrouped_all_documentation_approaches.xlsx", index=False
)
# Out:
#                                       Metadata element  \
# 0     Description of the process to access to raw data
# 1    Description of what is being tested in the dat...
# 2           Description of the recommended data splits
# 3                                                  NaN
# 4          Description of the dimensionality reduction
# ..                                                 ...
# 301                                                NaN
# 302  Description of domain specific concepts for ge...
# 303                                           Keywords
# 304  Description of the management plan for older v...
# 305  Description of the process for creating this d...
#
#                                              Datasheet  \
# 0    Was the “raw” data saved in addition to the pr...
# 1                                                  NaN
# 2    Are there recommended data splits (e.g., train...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304  Will older versions of the dataset continue to...
# 305                                                NaN
#
#                                   Data Nutrition Label  \
# 0    Was the raw data saved in addition to the prep...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303  Indicate up to five keywords relating to this ...
# 304                                                NaN
# 305                                                NaN
#
#                           Accountability Documentation  \
# 0                                                  NaN
# 1                                 What is being tested
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302  If relevant, brief summary of acronyms and dom...
# 303                                                NaN
# 304                                                NaN
# 305  Whose needs were consulted and synthesized whe...
#
#                                            Healthsheet  \
# 0    Was the “raw” data (post de-identification) sa...
# 1                                                  NaN
# 2    Does the current version/sub-version of the da...
# 3    Are there recommended data splits (e.g., train...
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304  Will older versions of the dataset continue to...
# 305                                                NaN
#
#                                              Data Card
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    How many original features were collected and ...
# ..                                                 ...
# 301  Provide a description of the expected performa...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
#
# [306 rows x 6 columns]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Comparison matrix

# %%
df_comparison = pd.DataFrame(index=list(dfs.keys()), columns=list(dfs.keys()))
for documentation1 in df_comparison.index:
    df1 = dfs[documentation1]
    for documentation2 in df_comparison.columns:
        df2 = dfs[documentation2]
        df_comparison.loc[documentation1, documentation2] = (
            len(
                [
                    i
                    for i in list(df1["Metadata element"])
                    if i in list(df2["Metadata element"])
                ]
            )
            / len(list(df1["Metadata element"]))
            * 100
        )
df_comparison.to_excel("outputs/metadata_elements_comparison_matrix.xlsx", index=False)
display(df_comparison)
# Out:
#                               Datasheet Data Nutrition Label  \
# Datasheet                         100.0            62.121212
# Data Nutrition Label           60.56338                100.0
# Accountability Documentation  32.911392            29.113924
# Healthsheet                   77.173913            51.086957
# Data Card                     32.768362            27.683616
#
#                              Accountability Documentation Healthsheet  \
# Datasheet                                       40.909091   98.484848
# Data Nutrition Label                            43.661972   67.605634
# Accountability Documentation                        100.0   40.506329
# Healthsheet                                     36.956522       100.0
# Data Card                                       28.813559   35.028249
#
#                               Data Card
# Datasheet                     37.878788
# Data Nutrition Label          36.619718
# Accountability Documentation   31.64557
# Healthsheet                   33.695652
# Data Card                         100.0

# %% [markdown]
# ### Occurence of metadata elements accross dataset documentation

# %%
elements_count_list = []
for metadata_element in metadata_elements_list:
    row = [metadata_element]
    for sheet, df in dfs.items():
        if metadata_element in list(df["Metadata element"]):
            row.append("Yes")
        else:
            row.append("No")
    row.append(len([i for i in row if i == "Yes"]))
    if metadata_element in critical_metadata_elements_list:
        row.append("Yes")
    else:
        row.append("No")
    elements_count_list.append(row)
df_element_count = pd.DataFrame(
    elements_count_list,
    columns=["Metadata element"] + list(dfs.keys()) + ["Count", "Critical"],
)
df_element_count = df_element_count.sort_values(by=["Count"], ascending=False)
df_element_count.to_excel("outputs/metadata_elements_count.xlsx", index=False)
display(df_element_count)
# Out:
#                                       Metadata element Datasheet  \
# 57            Details about the funding of the dataset       Yes
# 74              Description of the dataset update plan       Yes
# 38           Description of the dataset sharing method       Yes
# 58          Description of the data collection process       Yes
# 134     Description of the intended use of the dataset       Yes
# ..                                                 ...       ...
# 131  Information about the metadata repository and ...        No
# 133  Description of the factors in the data that mi...        No
# 135  Description of domain specific concepts for ge...        No
# 136                                           Keywords        No
# 138  Description of the process for creating this d...        No
#
#     Data Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 57                   Yes                          Yes         Yes       Yes
# 74                   Yes                          Yes         Yes       Yes
# 38                   Yes                          Yes         Yes       Yes
# 58                   Yes                          Yes         Yes       Yes
# 134                  Yes                          Yes         Yes       Yes
# ..                   ...                          ...         ...       ...
# 131                  Yes                           No          No        No
# 133                   No                           No         Yes        No
# 135                   No                          Yes          No        No
# 136                  Yes                           No          No        No
# 138                   No                          Yes          No        No
#
#      Count Critical
# 57       5      Yes
# 74       5      Yes
# 38       5      Yes
# 58       5      Yes
# 134      5      Yes
# ..     ...      ...
# 131      1       No
# 133      1      Yes
# 135      1       No
# 136      1       No
# 138      1      Yes
#
# [139 rows x 8 columns]

# %%
## Number of metadata elements and unique metadata elements per dataset documentation approach
count_metadata_elements = []
count_unique_metadata_elements = []
count_missing_critical_metadata_elements = []
labels = []
for doc in list(dfs.keys()):
    count_metadata_elements.append(df_element_count[doc].value_counts().get("Yes", 0))
    count_unique_metadata_elements.append(
        len(
            df_element_count[
                (df_element_count[doc] == "Yes") & (df_element_count["Count"] == 1)
            ]
        )
    )
    count_missing_critical_metadata_elements.append(
        len(critical_metadata_elements_list)
        - len(
            df_element_count[
                (df_element_count[doc] == "Yes")
                & (df_element_count["Critical"] == "Yes")
            ]
        )
    )
    if len(doc.split()) > 1:
        doc = "\n".join(doc.split())
    labels.append(doc)

# plot
fig, ax = plt.subplots(1, 1, figsize=(9, 6))

width = 0.25
y_list = [
    count_metadata_elements,
    count_unique_metadata_elements,
    count_missing_critical_metadata_elements,
]
labels_list = ["Total", "Unique", "Missing"]
x = np.arange(len(labels))
count = 0
for y in y_list:
    bars = ax.bar(
        x + width * count,
        y,
        width,
        color=colors[count],
        hatch=patterns[count],
        label=labels_list[count],
    )
    ax.bar_label(bars, padding=3)
    count += 1

ax.set_xticks(x + width, labels, fontsize=14)
ax.set_ylabel("Number of metadata elements", fontsize=14)
ax.set_axisbelow(True)
leg = ax.legend(loc="upper left", labelspacing=1, handlelength=2.5, facecolor="white")
for patch in leg.get_patches():
    patch.set_height(14)
    patch.set_y(-5)
ax.grid(axis="y", color="0.95")
plt.grid(color="0.95", axis="y")

fig.tight_layout()
fig.savefig("outputs/metadata_elements_view.png", dpi=200)

# %%
# Most common metadata descriptions
display(df_element_count[df_element_count["Count"] == 5])
# Out:
#                                    Metadata element Datasheet  \
# 57         Details about the funding of the dataset       Yes
# 74           Description of the dataset update plan       Yes
# 38        Description of the dataset sharing method       Yes
# 58       Description of the data collection process       Yes
# 134  Description of the intended use of the dataset       Yes
# 101     Information about the owners of the dataset       Yes
# 62                         Dataset publication date       Yes
#
#     Data Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 57                   Yes                          Yes         Yes       Yes
# 74                   Yes                          Yes         Yes       Yes
# 38                   Yes                          Yes         Yes       Yes
# 58                   Yes                          Yes         Yes       Yes
# 134                  Yes                          Yes         Yes       Yes
# 101                  Yes                          Yes         Yes       Yes
# 62                   Yes                          Yes         Yes       Yes
#
#      Count Critical
# 57       5      Yes
# 74       5      Yes
# 38       5      Yes
# 58       5      Yes
# 134      5      Yes
# 101      5      Yes
# 62       5      Yes

# %%
# Least common
for dataset_documentation in dfs.keys():
    print("----- Unique metadata description in " + dataset_documentation + " -----")
    df_unique = df_element_count[
        (df_element_count["Count"] == 1)
        & (df_element_count[dataset_documentation] == "Yes")
    ]
    display(df_unique)
# Out:
# ----- Unique metadata description in Datasheet -----
#                                      Metadata element Datasheet  \
# 40  Description of the possibilities to identify i...       Yes
#
#    Data Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 40                   No                           No          No        No
#
#     Count Critical
# 40      1      Yes
# ----- Unique metadata description in Data Nutrition Label -----
#                                       Metadata element Datasheet  \
# 9    Information the people consulted to create thi...        No
# 17   Required domain-specific knowledge for proper ...        No
# 11   Familiarity of creators of this dataset docume...        No
# 67    Description of representation issues in the data        No
# 63   Assumption in data fields not made explicit in...        No
# 65            Description of the individual-level data        No
# 35   Information about the format/structure of dataset        No
# 41   Description of the proxy characteristics in th...        No
# 98   Description of the strategies to avoid undesir...        No
# 114  Description of the involvement of the particip...        No
# 122      Description of issues related to this dataset        No
# 118                 Known issues with data collection         No
# 131  Information about the metadata repository and ...        No
# 136                                           Keywords        No
#
#     Data Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 9                    Yes                           No          No        No
# 17                   Yes                           No          No        No
# 11                   Yes                           No          No        No
# 67                   Yes                           No          No        No
# 63                   Yes                           No          No        No
# 65                   Yes                           No          No        No
# 35                   Yes                           No          No        No
# 41                   Yes                           No          No        No
# 98                   Yes                           No          No        No
# 114                  Yes                           No          No        No
# 122                  Yes                           No          No        No
# 118                  Yes                           No          No        No
# 131                  Yes                           No          No        No
# 136                  Yes                           No          No        No
#
#      Count Critical
# 9        1      Yes
# 17       1      Yes
# 11       1      Yes
# 67       1      Yes
# 63       1       No
# 65       1       No
# 35       1      Yes
# 41       1       No
# 98       1      Yes
# 114      1      Yes
# 122      1      Yes
# 118      1      Yes
# 131      1       No
# 136      1       No
# ----- Unique metadata description in Accountability Documentation -----
#                                       Metadata element Datasheet  \
# 1    Description of what is being tested in the dat...        No
# 5                  Description of the privacy handling        No
# 23   Description of the ethical impact of the data ...        No
# 18                  Link to requirements specification        No
# 13            Description and results of other testing        No
# 59   Description and results of the adversarial tes...        No
# 47   Description and results of the requirement tes...        No
# 55                                    Last update date        No
# 43          Information about the data collection cost        No
# 14   Description of the data distribution in the da...        No
# 15        Description of the data quality measurements        No
# 33           Expectations for people using the dataset        No
# 102      Description of the dataset processing process        No
# 91                             Link to design document        No
# 120                    Known caveats about the dataset        No
# 116                          List of related documents        No
# 107             Description of the data rating process        No
# 126           Description of the relevance of the data        No
# 125                    Description of related datasets        No
# 135  Description of domain specific concepts for ge...        No
# 138  Description of the process for creating this d...        No
#
#     Data Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 1                     No                          Yes          No        No
# 5                     No                          Yes          No        No
# 23                    No                          Yes          No        No
# 18                    No                          Yes          No        No
# 13                    No                          Yes          No        No
# 59                    No                          Yes          No        No
# 47                    No                          Yes          No        No
# 55                    No                          Yes          No        No
# 43                    No                          Yes          No        No
# 14                    No                          Yes          No        No
# 15                    No                          Yes          No        No
# 33                    No                          Yes          No        No
# 102                   No                          Yes          No        No
# 91                    No                          Yes          No        No
# 120                   No                          Yes          No        No
# 116                   No                          Yes          No        No
# 107                   No                          Yes          No        No
# 126                   No                          Yes          No        No
# 125                   No                          Yes          No        No
# 135                   No                          Yes          No        No
# 138                   No                          Yes          No        No
#
#      Count Critical
# 1        1      Yes
# 5        1      Yes
# 23       1      Yes
# 18       1       No
# 13       1       No
# 59       1       No
# 47       1       No
# 55       1       No
# 43       1      Yes
# 14       1       No
# 15       1      Yes
# 33       1       No
# 102      1      Yes
# 91       1       No
# 120      1       No
# 116      1       No
# 107      1       No
# 126      1       No
# 125      1       No
# 135      1       No
# 138      1      Yes
# ----- Unique metadata description in Healthsheet -----
#                                       Metadata element Datasheet  \
# 12   Description of the strategies to avoid reident...        No
# 48              Countries where the data was collected        No
# 46       Number of subjects represented in the dataset        No
# 54                  Guidelines for creating new labels        No
# 21   Information about the dataset documentation fo...        No
# 90         Description of the study inclusion criteria        No
# 106  Information about the dataset versioning approach        No
# 104  Description of the choice(s) of language for c...        No
# 99       Description of the accessibility measurements        No
# 86   Description of the regulation preventing demog...        No
# 115  Description of the confounding factors that mi...        No
# 133  Description of the factors in the data that mi...        No
#
#     Data Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 12                    No                           No         Yes        No
# 48                    No                           No         Yes        No
# 46                    No                           No         Yes        No
# 54                    No                           No         Yes        No
# 21                    No                           No         Yes        No
# 90                    No                           No         Yes        No
# 106                   No                           No         Yes        No
# 104                   No                           No         Yes        No
# 99                    No                           No         Yes        No
# 86                    No                           No         Yes        No
# 115                   No                           No         Yes        No
# 133                   No                           No         Yes        No
#
#      Count Critical
# 12       1      Yes
# 48       1      Yes
# 46       1      Yes
# 54       1      Yes
# 21       1       No
# 90       1      Yes
# 106      1       No
# 104      1      Yes
# 99       1       No
# 86       1       No
# 115      1      Yes
# 133      1      Yes
# ----- Unique metadata description in Data Card -----
#                                       Metadata element Datasheet  \
# 10                  Other dataset metrics besides size        No
# 3          Description of the dimensionality reduction        No
# 42                  Description of the aggregated data        No
# 25   Description of limitations of the dataset comp...        No
# 69   Definition of the acronyms and concepts used i...        No
# 70   Description of the alignment of the dataset wi...        No
# 61            Description of the human data attributes        No
# 66   Recommendations when this data is used with ot...        No
# 60       Description and handling of mismatched values        No
# 44                          Details of the data points        No
# 45         Description of the dataset deletion process        No
# 50   Description of benefits of the dataset compare...        No
# 19           Recommendations when sampling the dataset        No
# 30          Description of the data exclusion criteria        No
# 29   Description of the prerequisites to access thi...        No
# 34            Information about the dataset publishers        No
# 32   Description of the redacted or anonymized feat...        No
# 37   Information about risks when used with other data        No
# 103  Description of the data selection and inclusio...        No
# 92   Description of the process to mitigate risk fr...        No
# 93            Description and handling of the outliers        No
# 87             Description of the joint inputs sourced        No
# 80                    Statistics about each data field        No
# 81          Description of the data validation process        No
# 109                         Description of annotations        No
# 108  Information about the first version of the dat...        No
# 117                         Dataset maintenance status        No
# 123               Description of other transformations        No
# 132         Recommendations when used in AI/ML systems        No
#
#     Data Nutrition Label Accountability Documentation Healthsheet Data Card  \
# 10                    No                           No          No       Yes
# 3                     No                           No          No       Yes
# 42                    No                           No          No       Yes
# 25                    No                           No          No       Yes
# 69                    No                           No          No       Yes
# 70                    No                           No          No       Yes
# 61                    No                           No          No       Yes
# 66                    No                           No          No       Yes
# 60                    No                           No          No       Yes
# 44                    No                           No          No       Yes
# 45                    No                           No          No       Yes
# 50                    No                           No          No       Yes
# 19                    No                           No          No       Yes
# 30                    No                           No          No       Yes
# 29                    No                           No          No       Yes
# 34                    No                           No          No       Yes
# 32                    No                           No          No       Yes
# 37                    No                           No          No       Yes
# 103                   No                           No          No       Yes
# 92                    No                           No          No       Yes
# 93                    No                           No          No       Yes
# 87                    No                           No          No       Yes
# 80                    No                           No          No       Yes
# 81                    No                           No          No       Yes
# 109                   No                           No          No       Yes
# 108                   No                           No          No       Yes
# 117                   No                           No          No       Yes
# 123                   No                           No          No       Yes
# 132                   No                           No          No       Yes
#
#      Count Critical
# 10       1       No
# 3        1      Yes
# 42       1      Yes
# 25       1       No
# 69       1      Yes
# 70       1       No
# 61       1       No
# 66       1      Yes
# 60       1      Yes
# 44       1       No
# 45       1      Yes
# 50       1       No
# 19       1      Yes
# 30       1      Yes
# 29       1      Yes
# 34       1      Yes
# 32       1      Yes
# 37       1      Yes
# 103      1      Yes
# 92       1      Yes
# 93       1      Yes
# 87       1      Yes
# 80       1       No
# 81       1      Yes
# 109      1      Yes
# 108      1       No
# 117      1      Yes
# 123      1       No
# 132      1      Yes
